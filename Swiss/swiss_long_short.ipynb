# %%
# Start writing code here...
import pandas as pd
import numpy as np
import yfinance as yf

# %%
st = pd.read_csv("swiss.csv")
weekly = pd.DataFrame()    
for s in st.values:
    stock = s[0]
    tickers = yf.Ticker(stock)
    df = tickers.history(period = "10y")
    try:
        weekly[stock] = df.Close.resample('W-FRI').last()/df.Open.resample('W-FRI').first()-1
    except Exception as e:
        print(e)
        continue
    #print(stock)
    #break
weekly
# Out:
# - VET.SW: No data found, symbol may be delisted
# Only valid with DatetimeIndex, TimedeltaIndex or PeriodIndex, but got an instance of 'Index'
# - ZG.SW: No data found, symbol may be delisted
# Only valid with DatetimeIndex, TimedeltaIndex or PeriodIndex, but got an instance of 'Index'
#                  AEVS.SW   ALPN.SW   APGN.SW   ASCN.SW   ASWN.SW   BANB.SW  \
# Date
# 2011-02-04 -2.876779e-09  0.002907 -0.006433  0.047619       NaN  0.025408
# 2011-02-11  2.652445e-03  0.011561 -0.030173  0.006993       NaN  0.013465
# 2011-02-18 -5.263227e-03  0.011429  0.024024 -0.007067       NaN  0.003546
# 2011-02-25  5.291075e-03  0.000000 -0.015340 -0.043165       NaN  0.000899
# 2011-03-04 -2.631576e-03 -0.005618  0.116541  0.026515       NaN  0.041556
# ...                  ...       ...       ...       ...       ...       ...
# 2021-01-08  2.400002e-02  0.000000  0.022380 -0.021180 -0.132432 -0.002506
# 2021-01-15 -3.515623e-02  0.007299 -0.035000  0.026275 -0.040248 -0.045113
# 2021-01-22 -2.419349e-02  0.007246 -0.012409  0.044910  0.062500 -0.038058
# 2021-01-29  2.892557e-02 -0.007194 -0.015707  0.085106 -0.053073 -0.032564
# 2021-02-05 -1.209674e-02  0.000000 -0.008556  0.014360  0.011940  0.021008
#
#              LINN.SW   BCGE.SW        BCJ.SW   BCVN.SW  ...   UHRN.SW  \
# Date                                                    ...
# 2011-02-04  0.000000  0.004980 -8.130081e-03 -0.009479  ...  0.020513
# 2011-02-11  0.010753  0.002252 -1.803262e-02 -0.004762  ...  0.072194
# 2011-02-18  0.010638  0.002722 -1.524851e-07  0.006667  ... -0.015904
# 2011-02-25 -0.001612 -0.008948  0.000000e+00 -0.028409  ... -0.037037
# 2011-03-04  0.006522  0.013176  0.000000e+00 -0.025048  ... -0.012517
# ...              ...       ...           ...       ...  ...       ...
# 2021-01-08 -0.009804  0.000000 -3.603604e-02  0.005181  ...  0.007660
# 2021-01-15  0.010000 -0.018987 -1.869159e-02 -0.022774  ...  0.011008
# 2021-01-22  0.040000  0.000000  3.809524e-02  0.002114  ...  0.048724
# 2021-01-29  0.000000 -0.006410 -2.752294e-02 -0.010471  ... -0.000994
# 2021-02-05 -0.009804  0.012903  0.000000e+00  0.016878  ... -0.004970
#
#              TKBP.SW   TOHN.SW       VATN.SW   VAHN.SW   VILN.SW  \
# Date
# 2011-02-04       NaN  0.007634  8.733555e-03 -0.000929 -0.000955
# 2011-02-11       NaN -0.014925 -9.366088e-03  0.082166       NaN
# 2011-02-18       NaN -0.037879 -1.409943e-07 -0.006873  0.000000
# 2011-02-25       NaN -0.019608 -2.259467e-02 -0.032657 -0.009174
# 2011-03-04       NaN  0.044355 -8.221316e-03  0.062271       NaN
# ...              ...       ...           ...       ...       ...
# 2021-01-08 -0.009662  0.083825  2.068969e-02 -0.023158 -0.051613
# 2021-01-15 -0.009709 -0.051087 -3.163845e-02 -0.027897  0.020408
# 2021-01-22 -0.009756  0.284091  8.206295e-03  0.028446 -0.020000
# 2021-01-29 -0.004878 -0.109029 -1.726122e-02 -0.002155  0.013605
# 2021-02-05  0.009852 -0.019048 -1.851850e-02 -0.015054  0.006711
#
#                  WKBN.SW   YPSN.SW   ZEHN.SW    ZWM.SW
# Date
# 2011-02-04  1.412466e-03 -0.008972 -0.012951 -0.081633
# 2011-02-11 -1.207241e-08  0.004149  0.002762  0.151087
# 2011-02-18  6.987573e-04  0.028333  0.016135 -0.022222
# 2011-02-25  6.944527e-03 -0.031457 -0.040462  0.000000
# 2011-03-04  5.517260e-03 -0.018933 -0.002417 -0.108696
# ...                  ...       ...       ...       ...
# 2021-01-08  4.807692e-03 -0.015894  0.125839  0.011173
# 2021-01-15 -3.365385e-02 -0.030708 -0.037313  0.022099
# 2021-01-22  4.950495e-03  0.053571  0.018576  0.076087
# 2021-01-29 -1.960784e-02 -0.015686 -0.018100 -0.038835
# 2021-02-05  0.000000e+00  0.025333  0.027778  0.000000
#
# [523 rows x 83 columns]

# %%
weekly.fillna(-1).rank(axis=1)
# Out:
#             AEVS.SW  ALPN.SW  APGN.SW  ASCN.SW  ASWN.SW  BANB.SW  LINN.SW  \
# Date
# 2011-02-04     34.0     46.0     27.0     77.0      6.0     69.0     37.0
# 2011-02-11     50.0     63.0     15.0     58.0      6.5     65.0     62.0
# 2011-02-18     29.0     64.0     73.0     25.0      5.5     55.0     62.0
# 2011-02-25     67.0     56.5     39.0     17.0      5.5     63.0     51.0
# 2011-03-04     36.0     30.0     81.0     66.0      6.5     70.0     54.0
# ...             ...      ...      ...      ...      ...      ...      ...
# 2021-01-08     55.0     31.0     53.0      8.0      1.0     26.0     19.0
# 2021-01-15     16.0     60.0     17.0     75.0     10.0      8.0     64.0
# 2021-01-22      9.0     45.0     16.0     67.0     75.0      6.0     64.0
# 2021-01-29     80.0     43.0     32.0     82.0      7.0     20.0     56.0
# 2021-02-05     21.0     43.0     29.0     67.0     64.0     73.0     25.0
#
#             BCGE.SW  BCJ.SW  BCVN.SW  ...  UHRN.SW  TKBP.SW  TOHN.SW  VATN.SW  \
# Date                                  ...
# 2011-02-04     53.0    24.0     22.0  ...     65.0      6.0     58.0     59.0
# 2011-02-11     49.0    21.0     31.0  ...     79.0      6.5     22.0     27.0
# 2011-02-18     52.0    33.0     57.0  ...     17.0      5.5     12.0     34.0
# 2011-02-25     44.0    56.5     27.0  ...     23.0      5.5     34.0     30.0
# 2011-03-04     60.0    43.0     17.0  ...     21.0      6.5     73.0     29.0
# ...             ...     ...      ...  ...      ...      ...      ...      ...
# 2021-01-08     31.0     6.0     39.0  ...     46.0     20.0     76.0     52.0
# 2021-01-15     28.0    30.0     27.0  ...     66.0     42.0      4.0     20.0
# 2021-01-22     32.5    62.0     37.0  ...     70.0     19.0     82.0     47.0
# 2021-01-29     44.0    23.0     40.0  ...     53.0     46.0      1.0     31.0
# 2021-02-05     65.0    43.0     71.0  ...     31.0     61.0     13.0     14.0
#
#             VAHN.SW  VILN.SW  WKBN.SW  YPSN.SW  ZEHN.SW  ZWM.SW
# Date
# 2011-02-04     31.0     30.0     43.0     23.0     19.0    12.0
# 2011-02-11     81.0      6.5     41.0     56.0     51.0    83.0
# 2011-02-18     28.0     38.0     44.0     76.0     69.0    15.0
# 2011-02-25     24.0     43.0     69.0     25.0     20.0    56.5
# 2011-03-04     76.0      6.5     53.0     19.0     37.0    13.0
# ...             ...      ...      ...      ...      ...     ...
# 2021-01-08      7.0      3.0     37.0     11.0     82.0    47.0
# 2021-01-15     23.0     72.0     18.0     21.0     12.0    73.0
# 2021-01-22     58.0     11.0     40.0     71.0     53.0    78.0
# 2021-01-29     51.0     71.0     28.0     33.0     30.0    15.0
# 2021-02-05     16.0     56.0     43.0     78.0     80.0    43.0
#
# [523 rows x 83 columns]

# %%
bins = weekly.fillna(-1).rank(axis=1).apply(lambda x : x/10 , axis=1).astype(int)

# %% [markdown]
# now wee need to figure out the average next value per bin see if there is any predictive power to that

# %%
for i in range(0, bins.max().max()):
    next = bins.applymap(lambda x:1 if x == i else np.nan)*bins.shift(-1)
    nextperf = bins.applymap(lambda x:1 if x == i else np.nan)*weekly.fillna(-1).shift(-1)
    print((i, next.mean().mean(), nextperf.mean().mean()))
# Out:
# (0, 3.5236853329346185, -0.10284993609783247)
# (1, 4.114966584737986, 0.003539013015690242)
# (2, 4.001444926797342, 0.002505831894810169)
# (3, 4.0259962996102505, 0.003190164885535651)
# (4, 3.9151943599812964, 5.5934461393763335e-05)
# (5, 3.936135327913716, 0.0006933823341492567)
# (6, 3.95798320216316, 0.001534800782565034)
# (7, 3.7969277644278807, -2.493206833848386e-05)

# %% [markdown]
# looks like we need to short the worse performers and go long the best performers and get a really good ratio

# %%
short_bin = 1
long_bin = 7

# %%
def get_perf(short_bin, long_bin, weekly):
    bins = weekly.fillna(-1).rank(axis=1).apply(lambda x : x/10 , axis=1).astype(int)
    short = bins.applymap(lambda x:1 if x == short_bin else np.nan)*weekly.fillna(-1).shift(-1)
    longs = bins.applymap(lambda x:1 if x == long_bin else np.nan)*weekly.fillna(-1).shift(-1)
    res = (longs.mean(axis=1)-short.mean(axis=1)+1).cumprod()
    return res

def plot_perf(short_bin, long_bin, weekly, msg):
    res = get_perf(short_bin, long_bin, weekly)
    res.plot(figsize =(15, 10), legend=True, title=msg)
    return res

# %%
sr = []

for j in range(0, 9):
    for i in range(0, 9):
        if i < j:
            res = get_perf(j, i, weekly)
            if res[-2] > 4 and res[-2] < 6:
                print(f"+{i} -{j}")
                res = plot_perf(j,i,weekly, msg=f"+{i} -{j}")
                sr.append([i, j, res[-2]/res.dropna().std()])
            # if res[-1] > 2:
            #     break
#print(f"+{i} -{j}")
# Out:
# +1 -5
# +1 -7
# +1 -8

# %%
sr
# Out:
# [[1, 5, 3.920605602146694],
#  [1, 7, 3.800252400641494],
#  [1, 8, 3.112316683683135]]

# %%
plot_perf(5,3,weekly, msg=f"+{i} -{j}")
# Out:
# Date
# 2011-02-04    0.908160
# 2011-02-11    0.905835
# 2011-02-18    0.917914
# 2011-02-25    1.037789
# 2011-03-04    1.039755
#                 ...
# 2021-01-08    3.438419
# 2021-01-15    3.468365
# 2021-01-22    3.490694
# 2021-01-29    3.486091
# 2021-02-05         NaN
# Freq: W-FRI, Length: 523, dtype: float64

# %%
plot_perf(7,3,weekly, msg=f"+{i} -{j}")
# Out:
# Date
# 2011-02-04    0.905754
# 2011-02-11    0.897895
# 2011-02-18    0.900171
# 2011-02-25    0.912504
# 2011-03-04    0.930722
#                 ...
# 2021-01-08    3.846057
# 2021-01-15    3.825480
# 2021-01-22    3.879689
# 2021-01-29    3.849530
# 2021-02-05         NaN
# Freq: W-FRI, Length: 523, dtype: float64

# %%
res.dropna()[-2]
# Out:
# 0.9556709402190599

# %%
short = bins.applymap(lambda x:1 if x == short_bin else np.nan)*weekly.fillna(-1).shift(-1)
longs = bins.applymap(lambda x:1 if x == long_bin else np.nan)*weekly.fillna(-1).shift(-1)
longs.mean(axis=1)
short.mean(axis=1)
# Out:
# Date
# 2011-02-04    0.027571
# 2011-02-11    0.010901
# 2011-02-18   -0.009462
# 2011-02-25    0.024898
# 2011-03-04    0.010057
#                 ...
# 2021-01-08   -0.002456
# 2021-01-15   -0.000292
# 2021-01-22   -0.002101
# 2021-01-29    0.005688
# 2021-02-05         NaN
# Freq: W-FRI, Length: 523, dtype: float64

# %%
(longs.mean(axis=1)-short.mean(axis=1)+1).cumprod().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
(longs.mean(axis=1)-short.mean(axis=1)+1).tail(20)
# Out:
# Date
# 2020-09-25    0.993114
# 2020-10-02    0.999055
# 2020-10-09    0.981434
# 2020-10-16    0.988028
# 2020-10-23    1.002650
# 2020-10-30    0.959841
# 2020-11-06    0.998447
# 2020-11-13    0.988328
# 2020-11-20    1.030424
# 2020-11-27    0.991762
# 2020-12-04    1.002142
# 2020-12-11    0.993207
# 2020-12-18    1.008527
# 2020-12-25    0.989970
# 2021-01-01    1.002219
# 2021-01-08    1.001242
# 2021-01-15    1.015854
# 2021-01-22    0.980777
# 2021-01-29    0.799983
# 2021-02-05         NaN
# Freq: W-FRI, dtype: float64
