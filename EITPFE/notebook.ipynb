# %%
import pandas as pd

# %%
df = pd.read_csv("trades1.csv")
df.tail()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /opt/venv/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /opt/venv/lib/python3.7/site-packages/pandas/core/frame.py in _repr_html_(self)
#     732             self.info(buf=buf)
#     733             return buf.getvalue()
# --> 734
#     735         max_rows = get_option("display.max_rows")
#     736         min_rows = get_option("display.min_rows")
#
# /opt/venv/lib/python3.7/site-packages/pandas/io/formats/format.py in to_html(self, buf, encoding, classes, notebook, border)
#     980             Whether the generated HTML is for IPython Notebook.
#     981         border : int
# ...

# %%
dfa = df[df.Quantity<0]

# %%
dfg = dfa.groupby("Symbol").mean()['pastPerfAvg']
dfg.sort_values().tail(10)
# Out:
# Symbol
# MU      0.002889
# GOOG    0.003034
# BKNG    0.003518
# EXPE    0.003631
# MELI    0.003888
# TSLA    0.004100
# AMZN    0.004309
# NVDA    0.004377
# NFLX    0.006021
# AMD     0.006956
# Name: pastPerfAvg, dtype: float64

# %%
dfa
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /opt/venv/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /opt/venv/lib/python3.7/site-packages/pandas/core/frame.py in _repr_html_(self)
#     732             self.info(buf=buf)
#     733             return buf.getvalue()
# --> 734
#     735         max_rows = get_option("display.max_rows")
#     736         min_rows = get_option("display.min_rows")
#
# /opt/venv/lib/python3.7/site-packages/pandas/io/formats/format.py in to_html(self, buf, encoding, classes, notebook, border)
#     980             Whether the generated HTML is for IPython Notebook.
#     981         border : int
# ...

# %%
dfb = dfa[dfa.Symbol=='GOOG']
dfb.curPerf.plot()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-d463988a35b1> in <module>
#       1 dfb = dfa[dfa.Symbol=='GOOG']
# ----> 2 dfb.curPerf.plot()
#
# /opt/venv/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     765
#     766     @staticmethod
# --> 767     def _get_call_args(backend_name, data, args, kwargs):
#     768         """
#     769         This function makes calls to this accessor `__call__` method compatible
#
# /opt/venv/lib/python3.7/site-packages/pandas/plotting/_core.py in _get_plot_backend(backend)
#    1667
#    1668         .. plot::
# -> 1669             :context: close-figs
#    1670
#    1671             >>> n = 10000
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.

# %%
dfb.pastPerfAvg.plot()
